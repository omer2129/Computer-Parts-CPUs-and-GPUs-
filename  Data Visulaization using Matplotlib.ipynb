# %%
import pandas as pd
import numpy as np
path="F:/DataWrangling_part2.csv"
df=pd.read_csv(path)
import numpy as np

# %%
plt.plot(['DVI_Connection','HDMI_Connection'],['DisplayPort_Connection','VGA_Connection'])
plt.show()

# %%
x = ['DVI_Connection','HDMI_Connection']
y = ['DisplayPort_Connection','VGA_Connection']
plt.figure(figsize=(8,5))
plt.plot(['DVI_Connection','HDMI_Connection', 'Shader'],['DisplayPort_Connection','VGA_Connection','TMUs'],"go",x, y,"r^")
plt.title("Plot Testing")
plt.ylabel("Y Label")
plt.xlabel("X label")
plt.show()

# %%
avg_DisplayPort_Connection = round(df["DisplayPort_Connection"].astype("float").mean(axis=0))
avg_DVI_Connection = round(df["DVI_Connection"].astype("float").mean(axis=0))
avg_HDMI_Connection = round(df["HDMI_Connection"].astype("float").mean(axis=0))
Shader = round(df["Shader"].astype("float").mean(axis=0))
avg_VGA_Connection = round(df["VGA_Connection"].astype("float").mean(axis=0))
avg_TMUs = round(df["TMUs"].astype("float").mean(axis=0))
avg_Open_GL = round(df["Open_GL"].astype("float").mean(axis=0))

# %%
features = ["DisplayPort_Connection", "DVI_Connection", "HDMI_Connection", "Shader", "VGA_Connection", "TMUs", "Open_GL"]
counts = [avg_DisplayPort_Connection, avg_DVI_Connection, avg_HDMI_Connection, Shader, avg_VGA_Connection, avg_TMUs, avg_Open_GL]
f, ax = plt.subplots(figsize=(15,10))
plt.bar(features,counts,color='rgb')
plt.title('Features')
plt.ylabel("Features")
plt.xlabel("Average")
plt.show()

# %%
features = ["DisplayPort_Connection", "DVI_Connection", "HDMI_Connection", "Shader", "VGA_Connection", "TMUs", "Open_GL"]
counts = [avg_DisplayPort_Connection, avg_DVI_Connection, avg_HDMI_Connection, Shader, avg_VGA_Connection, avg_TMUs, avg_Open_GL]
sp = [1,0.1,1,0.1,1,0.1,1]
fig1, ax1 = plt.subplots(figsize=(18, 12))
plt.pie(counts ,explode = sp, labels=features,shadow=True, startangle=90,autopct='%50.2f')
plt.axis('equal')
plt.legend(title='Features')
plt.show()
