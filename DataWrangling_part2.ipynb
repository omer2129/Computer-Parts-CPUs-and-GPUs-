# %%
import pandas as pd
import numpy as np

# %%
path="C:/Users/Taha/Desktop/Data_wrangling_PART_1.csv"
df=pd.read_csv(path)

# %%
df["Memory_Type"].isnull().sum()
# Out:
# 30

# %%
df["Memory_Type"].value_counts()
# Out:
# GDDR5     2017
# DDR3       648
# GDDR3      294
# DDR        105
# DDR2        95
# GDDR5X      79
# DDR4        51
# HBM-1        6
# HBM-2        6
# GDDR2        5
# GDDR4        5
# eDRAM        3
# Name: Memory_Type, dtype: int64

# %%
MAX = df["Memory_Type"].value_counts().idxmax()
print(MAX)
# Out:
# GDDR5

# %%
df["Memory_Type"].replace(np.nan, MAX, inplace=True)

# %%
df.head(20)
# Out:
#     Unnamed: 0                Architecture Best_Resolution Boost_Clock  \
# 0            0                 Tesla G92b      1920 x 1080   1050 MHz
# 1            1                    R600 XT       1366 x 768   1050 MHz
# 2            2                   R600 PRO       1366 x 768   1050 MHz
# 3            3                      RV630       1024 x 768   1050 MHz
# 4            4                      RV630       1024 x 768   1050 MHz
# 5            5                      RV630       1024 x 768   1050 MHz
# 6            6              R700 RV790 XT      1920 x 1080   1050 MHz
# 7            7                    R600 GT       1024 x 768   1050 MHz
# 8            8             Pitcairn XT GL      1920 x 1080   1050 MHz
# 9            9                      RV100      1920 x 1080   1050 MHz
# 10          10                  NV28GL A2      1920 x 1080   1050 MHz
# 11          11                Fermi GF110      1920 x 1080   1050 MHz
# ...

# %%
df["Memory_Type"].isnull().sum()
# Out:
# 0

# %%
df["Name"].isnull().sum()
# Out:
# 0

# %%
df["Notebook_GPU"].isnull().sum()
# Out:
# 0

# %%
df["Open_GL"].isnull().sum()
# Out:
# 25

# %%
avg=df["Open_GL"].astype("float").mean(axis=0)
print(avg)
# Out:
# 4.040042181379913

# %%
df["Open_GL"].replace(np.nan, avg, inplace=True)

# %%
df.head(20)
# Out:
#     Unnamed: 0                Architecture Best_Resolution Boost_Clock  \
# 0            0                 Tesla G92b      1920 x 1080   1050 MHz
# 1            1                    R600 XT       1366 x 768   1050 MHz
# 2            2                   R600 PRO       1366 x 768   1050 MHz
# 3            3                      RV630       1024 x 768   1050 MHz
# 4            4                      RV630       1024 x 768   1050 MHz
# 5            5                      RV630       1024 x 768   1050 MHz
# 6            6              R700 RV790 XT      1920 x 1080   1050 MHz
# 7            7                    R600 GT       1024 x 768   1050 MHz
# 8            8             Pitcairn XT GL      1920 x 1080   1050 MHz
# 9            9                      RV100      1920 x 1080   1050 MHz
# 10          10                  NV28GL A2      1920 x 1080   1050 MHz
# 11          11                Fermi GF110      1920 x 1080   1050 MHz
# ...

# %%
df["Open_GL"].isnull().sum()
# Out:
# 0

# %%
df["PSU"].isnull().sum()
# Out:
# 1129

# %%
df["PSU"].value_counts()
# Out:
# 500 Watt & 33 Amps    259
# 600 Watt & 42 Amps    221
# 450 Watt & 30 Amps    137
# 400 Watt & 29 Amps    122
# 400 Watt & 27 Amps    110
#                      ...
# 600 Watt & 26 Amps      1
# 850 Watt & 62 Amps      1
# 1000 Watt               1
# 400 Watt & 30 Amps      1
# 500 Watt & 34 Amps      1
# Name: PSU, Length: 137, dtype: int64

# %%
MAX = df["PSU"].value_counts().idxmax()
print(MAX)
# Out:
# 500 Watt & 33 Amps

# %%
df["PSU"].replace(np.nan,MAX, inplace=True)

# %%
df.head(20)
# Out:
#     Unnamed: 0                Architecture Best_Resolution Boost_Clock  \
# 0            0                 Tesla G92b      1920 x 1080   1050 MHz
# 1            1                    R600 XT       1366 x 768   1050 MHz
# 2            2                   R600 PRO       1366 x 768   1050 MHz
# 3            3                      RV630       1024 x 768   1050 MHz
# 4            4                      RV630       1024 x 768   1050 MHz
# 5            5                      RV630       1024 x 768   1050 MHz
# 6            6              R700 RV790 XT      1920 x 1080   1050 MHz
# 7            7                    R600 GT       1024 x 768   1050 MHz
# 8            8             Pitcairn XT GL      1920 x 1080   1050 MHz
# 9            9                      RV100      1920 x 1080   1050 MHz
# 10          10                  NV28GL A2      1920 x 1080   1050 MHz
# 11          11                Fermi GF110      1920 x 1080   1050 MHz
# ...

# %%
df["PSU"].isnull().sum()
# Out:
# 0

# %%
df["Pixel_Rate"].isnull().sum()
# Out:
# 483

# %%
df["Pixel_Rate"].value_counts()
# Out:
# 3 GPixel/s      173
# 2 GPixel/s      130
# 17 GPixel/s      99
# 6 GPixel/s       84
# 8 GPixel/s       75
#                ...
# 156 GPixel/s      1
# 99 GPixel/s       1
# 246 GPixel/s      1
# 164 GPixel/s      1
# 260 GPixel/s      1
# Name: Pixel_Rate, Length: 159, dtype: int64

# %%
MAX = df["Pixel_Rate"].value_counts().idxmax()
print(MAX)
# Out:
# 3 GPixel/s

# %%
df["Pixel_Rate"].replace(np.nan, MAX, inplace=True)

# %%
df.head(20)
# Out:
#     Unnamed: 0                Architecture Best_Resolution Boost_Clock  \
# 0            0                 Tesla G92b      1920 x 1080   1050 MHz
# 1            1                    R600 XT       1366 x 768   1050 MHz
# 2            2                   R600 PRO       1366 x 768   1050 MHz
# 3            3                      RV630       1024 x 768   1050 MHz
# 4            4                      RV630       1024 x 768   1050 MHz
# 5            5                      RV630       1024 x 768   1050 MHz
# 6            6              R700 RV790 XT      1920 x 1080   1050 MHz
# 7            7                    R600 GT       1024 x 768   1050 MHz
# 8            8             Pitcairn XT GL      1920 x 1080   1050 MHz
# 9            9                      RV100      1920 x 1080   1050 MHz
# 10          10                  NV28GL A2      1920 x 1080   1050 MHz
# 11          11                Fermi GF110      1920 x 1080   1050 MHz
# ...

# %%
df["Pixel_Rate"].isnull().sum()
# Out:
# 0

# %%
df["Power_Connector"].value_counts()
# Out:
# None                      1613
# 1x 6-pin                   341
# 2x 6-pin                   251
# 1x 6-pin + 1x 8-pin        200
# 1x 8-pin                   154
# 2x 8-pin                    81
# 3x 8-pin                     8
# None                         5
# 4x 6-pin                     5
# 2x 6-pin                     2
# 1x 6-pin + 1x 8-pin\t        1
# Name: Power_Connector, dtype: int64

# %%
MAX = df["Power_Connector"].value_counts().idxmax()
print(MAX)
# Out:
# None

# %%
df["Power_Connector"].replace(np.nan, MAX, inplace=True)

# %%
df.head(20)
# Out:
#     Unnamed: 0                Architecture Best_Resolution Boost_Clock  \
# 0            0                 Tesla G92b      1920 x 1080   1050 MHz
# 1            1                    R600 XT       1366 x 768   1050 MHz
# 2            2                   R600 PRO       1366 x 768   1050 MHz
# 3            3                      RV630       1024 x 768   1050 MHz
# 4            4                      RV630       1024 x 768   1050 MHz
# 5            5                      RV630       1024 x 768   1050 MHz
# 6            6              R700 RV790 XT      1920 x 1080   1050 MHz
# 7            7                    R600 GT       1024 x 768   1050 MHz
# 8            8             Pitcairn XT GL      1920 x 1080   1050 MHz
# 9            9                      RV100      1920 x 1080   1050 MHz
# 10          10                  NV28GL A2      1920 x 1080   1050 MHz
# 11          11                Fermi GF110      1920 x 1080   1050 MHz
# ...

# %%
df["Power_Connector"].isnull().sum()
# Out:
# 0

# %%
df["Process"].value_counts()
# Out:
# 28nm     1490
# 40nm      620
# 14nm      310
# 16nm      205
# 55nm      110
# 65nm       61
# 80nm       44
# 22nm       40
# 32nm       23
# 90nm       15
# 150nm      12
# 130nm       6
# 110nm       4
# 100nm       1
# Name: Process, dtype: int64

# %%
MAX = df["Process"].value_counts().idxmax()
print(MAX)
# Out:
# 28nm

# %%
df["Process"].replace(np.nan, MAX, inplace=True)

# %%
df.head(20)
# Out:
#     Unnamed: 0                Architecture Best_Resolution Boost_Clock  \
# 0            0                 Tesla G92b      1920 x 1080   1050 MHz
# 1            1                    R600 XT       1366 x 768   1050 MHz
# 2            2                   R600 PRO       1366 x 768   1050 MHz
# 3            3                      RV630       1024 x 768   1050 MHz
# 4            4                      RV630       1024 x 768   1050 MHz
# 5            5                      RV630       1024 x 768   1050 MHz
# 6            6              R700 RV790 XT      1920 x 1080   1050 MHz
# 7            7                    R600 GT       1024 x 768   1050 MHz
# 8            8             Pitcairn XT GL      1920 x 1080   1050 MHz
# 9            9                      RV100      1920 x 1080   1050 MHz
# 10          10                  NV28GL A2      1920 x 1080   1050 MHz
# 11          11                Fermi GF110      1920 x 1080   1050 MHz
# ...

# %%
df["Process"].isnull().sum()
# Out:
# 0

# %%
df["ROPs"].value_counts()
# Out:
# 32         734
# 16         549
# 8          334
# 4          284
# 64         187
# 48         135
# 24         106
# 16 (x2)     87
# 32 (x2)     71
# 2           53
# 56          46
# 96          44
# 64 (x2)     30
# 22 (x4)     29
# 1           27
# 48 (x2)     20
# 40          19
# 24 (x2)     15
# 88          14
# 56 (x2)     12
# 96 (x2)     10
# 28           9
# 12           8
# 28 (x2)      6
# 3            4
# 16 (x4)      4
# 8 (x2)       4
# 20           3
# 44 (x2)      3
# 128          3
# 64 (x3)      2
# 48 (x4)      2
# 32 (x3)      2
# 40 (x2)      2
# 48 (x3)      1
# 22           1
# 14 (x2)      1
# 24 (x4)      1
# 6            1
# 4 (x4)       1
# 24 (x3)      1
# 32 (x4)      1
# Name: ROPs, dtype: int64

# %%
MAX = df["ROPs"].value_counts().idxmax()
print(MAX)
# Out:
# 32

# %%
df["ROPs"].replace(np.nan, MAX, inplace=True)

# %%
df.head(20)
# Out:
#     Unnamed: 0                Architecture Best_Resolution Boost_Clock  \
# 0            0                 Tesla G92b      1920 x 1080   1050 MHz
# 1            1                    R600 XT       1366 x 768   1050 MHz
# 2            2                   R600 PRO       1366 x 768   1050 MHz
# 3            3                      RV630       1024 x 768   1050 MHz
# 4            4                      RV630       1024 x 768   1050 MHz
# 5            5                      RV630       1024 x 768   1050 MHz
# 6            6              R700 RV790 XT      1920 x 1080   1050 MHz
# 7            7                    R600 GT       1024 x 768   1050 MHz
# 8            8             Pitcairn XT GL      1920 x 1080   1050 MHz
# 9            9                      RV100      1920 x 1080   1050 MHz
# 10          10                  NV28GL A2      1920 x 1080   1050 MHz
# 11          11                Fermi GF110      1920 x 1080   1050 MHz
# ...

# %%
df["ROPs"].isnull().sum()
# Out:
# 0

# %%
df["Release_Date"].value_counts()
# Out:
# \n18-Apr-2017     100
# \n19-Sep-2014      75
# \n08-Oct-2013      72
# \n18-Jun-2015      71
# \n01-Sep-2012      59
#                  ...
# \n18-Apr-2011       1
# \n08-Apr-2014       1
# \n13-Sep-2012       1
# \n23-Nov-2014       1
# \n10-Apr-2008       1
# Name: Release_Date, Length: 763, dtype: int64

# %%
MAX = df["Release_Date"].value_counts().idxmax()
print(MAX)
# Out:
# 18-Apr-2017

# %%
df["Release_Date"].replace(np.nan, MAX, inplace=True)

# %%
df.head(20)
# Out:
#     Unnamed: 0                Architecture Best_Resolution Boost_Clock  \
# 0            0                 Tesla G92b      1920 x 1080   1050 MHz
# 1            1                    R600 XT       1366 x 768   1050 MHz
# 2            2                   R600 PRO       1366 x 768   1050 MHz
# 3            3                      RV630       1024 x 768   1050 MHz
# 4            4                      RV630       1024 x 768   1050 MHz
# 5            5                      RV630       1024 x 768   1050 MHz
# 6            6              R700 RV790 XT      1920 x 1080   1050 MHz
# 7            7                    R600 GT       1024 x 768   1050 MHz
# 8            8             Pitcairn XT GL      1920 x 1080   1050 MHz
# 9            9                      RV100      1920 x 1080   1050 MHz
# 10          10                  NV28GL A2      1920 x 1080   1050 MHz
# 11          11                Fermi GF110      1920 x 1080   1050 MHz
# ...

# %%
df["Release_Date"].isnull().sum()
# Out:
# 0

# %%
df["Resolution_WxH"].value_counts()
# Out:
# 4096x2160    1330
# 2560x1600    1147
# 7680x4320     258
# 5120x3200     217
# 2048x1536      71
# 5120x2880      48
# 4096x2304      41
# 1600x1200      23
# 7680x3200       6
# 4096x3112       5
# 1920x1440       3
# 3840x2160       3
# 1600x900        2
# 1920x1200       2
# 1280x1024       2
# 1600x1280       1
# 1680x1050       1
# 5760x2160       1
# 5120x2160       1
# Name: Resolution_WxH, dtype: int64

# %%
MAX = df["Resolution_WxH"].value_counts().idxmax()
print(MAX)
# Out:
# 4096x2160

# %%
df["Resolution_WxH"].replace(np.nan, MAX, inplace=True)

# %%
df.head(20)
# Out:
#     Unnamed: 0                Architecture Best_Resolution Boost_Clock  \
# 0            0                 Tesla G92b      1920 x 1080   1050 MHz
# 1            1                    R600 XT       1366 x 768   1050 MHz
# 2            2                   R600 PRO       1366 x 768   1050 MHz
# 3            3                      RV630       1024 x 768   1050 MHz
# 4            4                      RV630       1024 x 768   1050 MHz
# 5            5                      RV630       1024 x 768   1050 MHz
# 6            6              R700 RV790 XT      1920 x 1080   1050 MHz
# 7            7                    R600 GT       1024 x 768   1050 MHz
# 8            8             Pitcairn XT GL      1920 x 1080   1050 MHz
# 9            9                      RV100      1920 x 1080   1050 MHz
# 10          10                  NV28GL A2      1920 x 1080   1050 MHz
# 11          11                Fermi GF110      1920 x 1080   1050 MHz
# ...

# %%
df["Release_Date"].isnull().sum()
# Out:
# 0

# %%
df["SLI_Crossfire"].value_counts()
# Out:
# Yes    1919
# No     1425
# Name: SLI_Crossfire, dtype: int64

# %%
MAX = df["SLI_Crossfire"].value_counts().idxmax()
print(MAX)
# Out:
# Yes

# %%
df["SLI_Crossfire"].replace(np.nan, MAX, inplace=True)

# %%
df.head(20)
# Out:
#     Unnamed: 0                Architecture Best_Resolution Boost_Clock  \
# 0            0                 Tesla G92b      1920 x 1080   1050 MHz
# 1            1                    R600 XT       1366 x 768   1050 MHz
# 2            2                   R600 PRO       1366 x 768   1050 MHz
# 3            3                      RV630       1024 x 768   1050 MHz
# 4            4                      RV630       1024 x 768   1050 MHz
# 5            5                      RV630       1024 x 768   1050 MHz
# 6            6              R700 RV790 XT      1920 x 1080   1050 MHz
# 7            7                    R600 GT       1024 x 768   1050 MHz
# 8            8             Pitcairn XT GL      1920 x 1080   1050 MHz
# 9            9                      RV100      1920 x 1080   1050 MHz
# 10          10                  NV28GL A2      1920 x 1080   1050 MHz
# 11          11                Fermi GF110      1920 x 1080   1050 MHz
# ...

# %%
df["SLI_Crossfire"].isnull().sum()
# Out:
# 0

# %%
df["Shader"].value_counts()
# Out:
# 5.0    2630
# 4.0     249
# 4.1     159
# 3.0     130
# 2.0      52
# 1.3      14
# 1.4       8
# 1.1       4
# 1.0       1
# Name: Shader, dtype: int64

# %%
MAX = df["Shader"].value_counts().idxmax()
print(MAX)
# Out:
# 5.0

# %%
df["Shader"].replace(np.nan, MAX, inplace=True)

# %%
df.head(20)
# Out:
#                   Architecture Best_Resolution Boost_Clock Core_Speed  \
# 0                  Tesla G92b              NaN         NaN    738 MHz
# 1                     R600 XT       1366 x 768         NaN       \n-
# 2                    R600 PRO       1366 x 768         NaN       \n-
# 3                       RV630       1024 x 768         NaN       \n-
# 4                       RV630       1024 x 768         NaN       \n-
# 5                       RV630       1024 x 768         NaN       \n-
# 6               R700 RV790 XT      1920 x 1080         NaN    870 MHz
# 7                     R600 GT       1024 x 768         NaN       \n-
# 8              Pitcairn XT GL      1920 x 1080         NaN       \n-
# 9                       RV100              NaN         NaN       \n-
# 10                  NV28GL A2              NaN         NaN       \n-
# 11                Fermi GF110      1920 x 1080         NaN    650 MHz
# ...

# %%
df["Shader"].isnull().sum()
# Out:
# 0

# %%
df["TMUs"].value_counts()
# Out:
# 64.0     295
# 32.0     245
# 128.0    221
# 8.0      217
# 16.0     190
# 56.0     178
# 40.0     172
# 80.0     166
# 24.0     163
# 112.0    147
# 48.0     125
# 176.0     88
# 72.0      79
# 4.0       74
# 96.0      67
# 160.0     62
# 104.0     59
# 20.0      56
# 144.0     44
# 192.0     39
# 120.0     38
# 224.0     29
# 240.0     24
# 60.0      21
# 1.0       12
# 88.0      12
# 36.0      11
# 256.0      9
# 44.0       6
# 2.0        6
# 12.0       3
# 384.0      2
# 320.0      2
# 28.0       2
# 14.0       1
# 106.0      1
# Name: TMUs, dtype: int64

# %%
MAX = df["TMUs"].value_counts().idxmax()
print(MAX)
# Out:
# 64.0

# %%
df["TMUs"].replace(np.nan, MAX, inplace=True)

# %%
df.head(20)
# Out:
#     Unnamed: 0                Architecture Best_Resolution Boost_Clock  \
# 0            0                 Tesla G92b      1920 x 1080   1050 MHz
# 1            1                    R600 XT       1366 x 768   1050 MHz
# 2            2                   R600 PRO       1366 x 768   1050 MHz
# 3            3                      RV630       1024 x 768   1050 MHz
# 4            4                      RV630       1024 x 768   1050 MHz
# 5            5                      RV630       1024 x 768   1050 MHz
# 6            6              R700 RV790 XT      1920 x 1080   1050 MHz
# 7            7                    R600 GT       1024 x 768   1050 MHz
# 8            8             Pitcairn XT GL      1920 x 1080   1050 MHz
# 9            9                      RV100      1920 x 1080   1050 MHz
# 10          10                  NV28GL A2      1920 x 1080   1050 MHz
# 11          11                Fermi GF110      1920 x 1080   1050 MHz
# ...

# %%
df["TMUs"].isnull().sum()
# Out:
# 0

# %%
df["Texture_Rate"].value_counts()
# Out:
# 5 GTexel/s      83
# 16 GTexel/s     60
# 4 GTexel/s      54
# 34 GTexel/s     51
# 14 GTexel/s     46
#                 ..
# 310 GTexel/s     1
# 464 GTexel/s     1
# 273 GTexel/s     1
# 237 GTexel/s     1
# 253 GTexel/s     1
# Name: Texture_Rate, Length: 315, dtype: int64

# %%
MAX = df["Texture_Rate"].value_counts().idxmax()
print(MAX)
# Out:
# 5 GTexel/s

# %%
df["Texture_Rate"].replace(np.nan, MAX, inplace=True)

# %%
df.head(20)
# Out:
#     Unnamed: 0                Architecture Best_Resolution Boost_Clock  \
# 0            0                 Tesla G92b      1920 x 1080   1050 MHz
# 1            1                    R600 XT       1366 x 768   1050 MHz
# 2            2                   R600 PRO       1366 x 768   1050 MHz
# 3            3                      RV630       1024 x 768   1050 MHz
# 4            4                      RV630       1024 x 768   1050 MHz
# 5            5                      RV630       1024 x 768   1050 MHz
# 6            6              R700 RV790 XT      1920 x 1080   1050 MHz
# 7            7                    R600 GT       1024 x 768   1050 MHz
# 8            8             Pitcairn XT GL      1920 x 1080   1050 MHz
# 9            9                      RV100      1920 x 1080   1050 MHz
# 10          10                  NV28GL A2      1920 x 1080   1050 MHz
# 11          11                Fermi GF110      1920 x 1080   1050 MHz
# ...

# %%
df["Texture_Rate"].isnull().sum()
# Out:
# 0

# %%
df["VGA_Connection"].value_counts()
# Out:
# 0.0    2075
# 1.0     535
# 2.0      11
# 4.0       2
# Name: VGA_Connection, dtype: int64

# %%
MAX = df["VGA_Connection"].value_counts().idxmax()
print(MAX)
# Out:
# 0.0

# %%
df["VGA_Connection"].replace(np.nan, MAX, inplace=True)

# %%
df.head(20)
# Out:
#     Unnamed: 0                Architecture Best_Resolution Boost_Clock  \
# 0            0                 Tesla G92b      1920 x 1080   1050 MHz
# 1            1                    R600 XT       1366 x 768   1050 MHz
# 2            2                   R600 PRO       1366 x 768   1050 MHz
# 3            3                      RV630       1024 x 768   1050 MHz
# 4            4                      RV630       1024 x 768   1050 MHz
# 5            5                      RV630       1024 x 768   1050 MHz
# 6            6              R700 RV790 XT      1920 x 1080   1050 MHz
# 7            7                    R600 GT       1024 x 768   1050 MHz
# 8            8             Pitcairn XT GL      1920 x 1080   1050 MHz
# 9            9                      RV100      1920 x 1080   1050 MHz
# 10          10                  NV28GL A2      1920 x 1080   1050 MHz
# 11          11                Fermi GF110      1920 x 1080   1050 MHz
# ...

# %%
df["VGA_Connection"].isnull().sum()
# Out:
# 0

# %%
df.to_csv('DataWrangling_part2.csv')
