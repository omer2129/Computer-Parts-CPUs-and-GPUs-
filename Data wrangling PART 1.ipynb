# %%
import pandas as pd
path="F:/All_GPUs.csv"
df=pd.read_csv(path)

# %%
import numpy as np
df.replace("?",np.nan, inplace=True)

# %%
df.dropna(subset=["Architecture"], axis=0, inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
df.head(40)
# Out:
#                   Architecture Best_Resolution Boost_Clock Core_Speed  \
# 0                  Tesla G92b              NaN         NaN    738 MHz
# 1                     R600 XT       1366 x 768         NaN        NaN
# 2                    R600 PRO       1366 x 768         NaN        NaN
# 3                       RV630       1024 x 768         NaN        NaN
# 4                       RV630       1024 x 768         NaN        NaN
# 5                       RV630       1024 x 768         NaN        NaN
# 6               R700 RV790 XT      1920 x 1080         NaN    870 MHz
# 7                     R600 GT       1024 x 768         NaN        NaN
# 8              Pitcairn XT GL      1920 x 1080         NaN        NaN
# 9                       RV100              NaN         NaN        NaN
# 10                  NV28GL A2              NaN         NaN        NaN
# 11                Fermi GF110      1920 x 1080         NaN    650 MHz
# ...

# %%
df["Architecture"].isnull().sum()
# Out:
# 0

# %%
df["Best_Resolution"].value_counts()
# Out:
# 1920 x 1080    869
# 1600 x 900     609
# 1366 x 768     503
# 2560 x 1440    290
# 2560 x 1600    157
# 1024 x 768     105
# 3840 x 2160     93
# 800 x 600       33
# 1440 x 900      30
# 1280 x 720      29
# 1680 x 1050     19
# 5760 x 1600     10
# 5760 x 1080      6
# 1920 x 800       3
# 1366 x 720       2
# 640 x 480        1
# 1600 x 960       1
# Name: Best_Resolution, dtype: int64

# %%
max_Best_Resolution = df["Best_Resolution"].value_counts().idxmax()
print(max_Best_Resolution)
# Out:
# 1920 x 1080

# %%
df["Best_Resolution"].replace(np.nan, max_Best_Resolution, inplace=True)

# %%
df.head(20)
# Out:
#                   Architecture Best_Resolution Boost_Clock Core_Speed  \
# 0                  Tesla G92b      1920 x 1080         NaN    738 MHz
# 1                     R600 XT       1366 x 768         NaN        NaN
# 2                    R600 PRO       1366 x 768         NaN        NaN
# 3                       RV630       1024 x 768         NaN        NaN
# 4                       RV630       1024 x 768         NaN        NaN
# 5                       RV630       1024 x 768         NaN        NaN
# 6               R700 RV790 XT      1920 x 1080         NaN    870 MHz
# 7                     R600 GT       1024 x 768         NaN        NaN
# 8              Pitcairn XT GL      1920 x 1080         NaN        NaN
# 9                       RV100      1920 x 1080         NaN        NaN
# 10                  NV28GL A2      1920 x 1080         NaN        NaN
# 11                Fermi GF110      1920 x 1080         NaN    650 MHz
# ...

# %%
df["Best_Resolution"].isnull().sum()
# Out:
# 0

# %%
df["Boost_Clock"].value_counts()
# Out:
# 1050 MHz     57
# 1150 MHz     44
# 1100 MHz     42
# 1266 MHz     33
# 1000 MHz     31
#              ..
# 1071 MHz      1
# 1267 MHz      1
# 1021 MHz      1
# 600 MHz       1
# 1431 MHz      1
# Name: Boost_Clock, Length: 223, dtype: int64

# %%
max_Boost_Clock = df["Boost_Clock"].value_counts().idxmax()
print(max_Boost_Clock)
# Out:
# 1050 MHz

# %%
df["Boost_Clock"].replace(np.nan, max_Boost_Clock, inplace=True)

# %%
df.head(20)
# Out:
#                   Architecture Best_Resolution Boost_Clock Core_Speed  \
# 0                  Tesla G92b      1920 x 1080   1050 MHz     738 MHz
# 1                     R600 XT       1366 x 768   1050 MHz         NaN
# 2                    R600 PRO       1366 x 768   1050 MHz         NaN
# 3                       RV630       1024 x 768   1050 MHz         NaN
# 4                       RV630       1024 x 768   1050 MHz         NaN
# 5                       RV630       1024 x 768   1050 MHz         NaN
# 6               R700 RV790 XT      1920 x 1080   1050 MHz     870 MHz
# 7                     R600 GT       1024 x 768   1050 MHz         NaN
# 8              Pitcairn XT GL      1920 x 1080   1050 MHz         NaN
# 9                       RV100      1920 x 1080   1050 MHz         NaN
# 10                  NV28GL A2      1920 x 1080   1050 MHz         NaN
# 11                Fermi GF110      1920 x 1080   1050 MHz     650 MHz
# ...

# %%
df["Boost_Clock"].isnull().sum()
# Out:
# 0

# %%
df["Core_Speed"].value_counts()
# Out:
# 1000 MHz    128
# 800 MHz      71
# 900 MHz      68
# 1050 MHz     60
# 1006 MHz     54
#            ...
# 951 MHz       1
# 615 MHz       1
# 1637 MHz      1
# 757 MHz       1
# 570 MHz       1
# Name: Core_Speed, Length: 295, dtype: int64

# %%
max_Core_Speed = df["Core_Speed"].value_counts().idxmax()
print(max_Core_Speed)
# Out:
# 1000 MHz

# %%
df["Core_Speed"].replace(np.nan, max_Core_Speed, inplace=True)

# %%
df.head(20)
# Out:
#                   Architecture Best_Resolution Boost_Clock Core_Speed  \
# 0                  Tesla G92b      1920 x 1080   1050 MHz     738 MHz
# 1                     R600 XT       1366 x 768   1050 MHz    1000 MHz
# 2                    R600 PRO       1366 x 768   1050 MHz    1000 MHz
# 3                       RV630       1024 x 768   1050 MHz    1000 MHz
# 4                       RV630       1024 x 768   1050 MHz    1000 MHz
# 5                       RV630       1024 x 768   1050 MHz    1000 MHz
# 6               R700 RV790 XT      1920 x 1080   1050 MHz     870 MHz
# 7                     R600 GT       1024 x 768   1050 MHz    1000 MHz
# 8              Pitcairn XT GL      1920 x 1080   1050 MHz    1000 MHz
# 9                       RV100      1920 x 1080   1050 MHz    1000 MHz
# 10                  NV28GL A2      1920 x 1080   1050 MHz    1000 MHz
# 11                Fermi GF110      1920 x 1080   1050 MHz     650 MHz
# ...

# %%
df["Core_Speed"].isnull().sum()
# Out:
# 0

# %%
df["DVI_Connection"].value_counts()
# Out:
# 1.0    1161
# 2.0    1147
# 0.0     288
# 4.0      23
# 3.0      11
# Name: DVI_Connection, dtype: int64

# %%
max_DVI_Connection = df["DVI_Connection"].value_counts().idxmax()
print(max_DVI_Connection)
# Out:
# 1.0

# %%
df["DVI_Connection"].replace(np.nan, max_DVI_Connection, inplace=True)

# %%
df.head(20)
# Out:
#                   Architecture Best_Resolution Boost_Clock Core_Speed  \
# 0                  Tesla G92b      1920 x 1080   1050 MHz     738 MHz
# 1                     R600 XT       1366 x 768   1050 MHz    1000 MHz
# 2                    R600 PRO       1366 x 768   1050 MHz    1000 MHz
# 3                       RV630       1024 x 768   1050 MHz    1000 MHz
# 4                       RV630       1024 x 768   1050 MHz    1000 MHz
# 5                       RV630       1024 x 768   1050 MHz    1000 MHz
# 6               R700 RV790 XT      1920 x 1080   1050 MHz     870 MHz
# 7                     R600 GT       1024 x 768   1050 MHz    1000 MHz
# 8              Pitcairn XT GL      1920 x 1080   1050 MHz    1000 MHz
# 9                       RV100      1920 x 1080   1050 MHz    1000 MHz
# 10                  NV28GL A2      1920 x 1080   1050 MHz    1000 MHz
# 11                Fermi GF110      1920 x 1080   1050 MHz     650 MHz
# ...

# %%
df["DVI_Connection"].isnull().sum()
# Out:
# 0

# %%
df["Dedicated"].value_counts()
# Out:
# Yes    2974
# No      357
# Name: Dedicated, dtype: int64

# %%
max_Dedicated = df["Dedicated"].value_counts().idxmax()
print(max_Dedicated)
# Out:
# Yes

# %%
df["Dedicated"].replace(np.nan, max_Dedicated, inplace=True)

# %%
df.head(20)
# Out:
#                   Architecture Best_Resolution Boost_Clock Core_Speed  \
# 0                  Tesla G92b      1920 x 1080   1050 MHz     738 MHz
# 1                     R600 XT       1366 x 768   1050 MHz    1000 MHz
# 2                    R600 PRO       1366 x 768   1050 MHz    1000 MHz
# 3                       RV630       1024 x 768   1050 MHz    1000 MHz
# 4                       RV630       1024 x 768   1050 MHz    1000 MHz
# 5                       RV630       1024 x 768   1050 MHz    1000 MHz
# 6               R700 RV790 XT      1920 x 1080   1050 MHz     870 MHz
# 7                     R600 GT       1024 x 768   1050 MHz    1000 MHz
# 8              Pitcairn XT GL      1920 x 1080   1050 MHz    1000 MHz
# 9                       RV100      1920 x 1080   1050 MHz    1000 MHz
# 10                  NV28GL A2      1920 x 1080   1050 MHz    1000 MHz
# 11                Fermi GF110      1920 x 1080   1050 MHz     650 MHz
# ...

# %%
df["Dedicated"].isnull().sum()
# Out:
# 0

# %%
df["Direct_X"].value_counts()
# Out:
# DX 12.0    1639
# DX 12.1     551
# DX 11.0     227
# DX 10.1     184
# DX 10       168
# DX 11        99
# DX 11.1      98
# DX 9.0c      83
# DX 10.0      71
# DX 11.2      50
# DX 9         50
# DX 9.0b      33
# DX 8.1       25
# DX 7.0       17
# DX 12        15
# DX 9.0       15
# DX 7          7
# DX 6.0        6
# DX 9.0a       2
# DX 8          1
# DX 5.0        1
# Name: Direct_X, dtype: int64

# %%
max_Direct_X = df["Direct_X"].value_counts().idxmax()
print(max_Direct_X)
# Out:
# DX 12.0

# %%
df["Direct_X"].replace(np.nan, max_Direct_X, inplace=True)

# %%
df.head(20)
# Out:
#                   Architecture Best_Resolution Boost_Clock Core_Speed  \
# 0                  Tesla G92b      1920 x 1080   1050 MHz     738 MHz
# 1                     R600 XT       1366 x 768   1050 MHz    1000 MHz
# 2                    R600 PRO       1366 x 768   1050 MHz    1000 MHz
# 3                       RV630       1024 x 768   1050 MHz    1000 MHz
# 4                       RV630       1024 x 768   1050 MHz    1000 MHz
# 5                       RV630       1024 x 768   1050 MHz    1000 MHz
# 6               R700 RV790 XT      1920 x 1080   1050 MHz     870 MHz
# 7                     R600 GT       1024 x 768   1050 MHz    1000 MHz
# 8              Pitcairn XT GL      1920 x 1080   1050 MHz    1000 MHz
# 9                       RV100      1920 x 1080   1050 MHz    1000 MHz
# 10                  NV28GL A2      1920 x 1080   1050 MHz    1000 MHz
# 11                Fermi GF110      1920 x 1080   1050 MHz     650 MHz
# ...

# %%
df["Direct_X"].isnull().sum()
# Out:
# 0

# %%
df["DisplayPort_Connection"].value_counts()
# Out:
# 3.0    314
# 1.0    252
# 0.0    204
# 2.0     80
# 4.0      7
# Name: DisplayPort_Connection, dtype: int64

# %%
avg_DisplayPort_Connection = round(df["DisplayPort_Connection"].astype("float").mean(axis=0))
print(avg_DisplayPort_Connection)
# Out:
# 2

# %%
df["DisplayPort_Connection"].replace(np.nan, avg_DisplayPort_Connection, inplace=True)

# %%
df.head(20)
# Out:
#                   Architecture Best_Resolution Boost_Clock Core_Speed  \
# 0                  Tesla G92b      1920 x 1080   1050 MHz     738 MHz
# 1                     R600 XT       1366 x 768   1050 MHz    1000 MHz
# 2                    R600 PRO       1366 x 768   1050 MHz    1000 MHz
# 3                       RV630       1024 x 768   1050 MHz    1000 MHz
# 4                       RV630       1024 x 768   1050 MHz    1000 MHz
# 5                       RV630       1024 x 768   1050 MHz    1000 MHz
# 6               R700 RV790 XT      1920 x 1080   1050 MHz     870 MHz
# 7                     R600 GT       1024 x 768   1050 MHz    1000 MHz
# 8              Pitcairn XT GL      1920 x 1080   1050 MHz    1000 MHz
# 9                       RV100      1920 x 1080   1050 MHz    1000 MHz
# 10                  NV28GL A2      1920 x 1080   1050 MHz    1000 MHz
# 11                Fermi GF110      1920 x 1080   1050 MHz     650 MHz
# ...

# %%
df["DisplayPort_Connection"].isnull().sum()
# Out:
# 0

# %%
df["HDMI_Connection"].value_counts()
# Out:
# 1.0    1998
# 0.0     516
# 2.0      97
# 3.0      10
# Name: HDMI_Connection, dtype: int64

# %%
max_HDMI_Connection = df["HDMI_Connection"].value_counts().idxmax()
print(max_HDMI_Connection)
# Out:
# 1.0

# %%
df["HDMI_Connection"].replace(np.nan, max_HDMI_Connection, inplace=True)

# %%
df.head(20)
# Out:
#                   Architecture Best_Resolution Boost_Clock Core_Speed  \
# 0                  Tesla G92b      1920 x 1080   1050 MHz     738 MHz
# 1                     R600 XT       1366 x 768   1050 MHz    1000 MHz
# 2                    R600 PRO       1366 x 768   1050 MHz    1000 MHz
# 3                       RV630       1024 x 768   1050 MHz    1000 MHz
# 4                       RV630       1024 x 768   1050 MHz    1000 MHz
# 5                       RV630       1024 x 768   1050 MHz    1000 MHz
# 6               R700 RV790 XT      1920 x 1080   1050 MHz     870 MHz
# 7                     R600 GT       1024 x 768   1050 MHz    1000 MHz
# 8              Pitcairn XT GL      1920 x 1080   1050 MHz    1000 MHz
# 9                       RV100      1920 x 1080   1050 MHz    1000 MHz
# 10                  NV28GL A2      1920 x 1080   1050 MHz    1000 MHz
# 11                Fermi GF110      1920 x 1080   1050 MHz     650 MHz
# ...

# %%
df["HDMI_Connection"].isnull().sum()
# Out:
# 0

# %%
df["Integrated"].value_counts()
# Out:
# No     2974
# Yes     357
# Name: Integrated, dtype: int64

# %%
max_Integrated = df["Integrated"].value_counts().idxmax()
print(max_Integrated)
# Out:
# No

# %%
df["Integrated"].replace(np.nan, max_Integrated, inplace=True)

# %%
df.head(20)
# Out:
#                   Architecture Best_Resolution Boost_Clock Core_Speed  \
# 0                  Tesla G92b      1920 x 1080   1050 MHz     738 MHz
# 1                     R600 XT       1366 x 768   1050 MHz    1000 MHz
# 2                    R600 PRO       1366 x 768   1050 MHz    1000 MHz
# 3                       RV630       1024 x 768   1050 MHz    1000 MHz
# 4                       RV630       1024 x 768   1050 MHz    1000 MHz
# 5                       RV630       1024 x 768   1050 MHz    1000 MHz
# 6               R700 RV790 XT      1920 x 1080   1050 MHz     870 MHz
# 7                     R600 GT       1024 x 768   1050 MHz    1000 MHz
# 8              Pitcairn XT GL      1920 x 1080   1050 MHz    1000 MHz
# 9                       RV100      1920 x 1080   1050 MHz    1000 MHz
# 10                  NV28GL A2      1920 x 1080   1050 MHz    1000 MHz
# 11                Fermi GF110      1920 x 1080   1050 MHz     650 MHz
# ...

# %%
df["Integrated"].isnull().sum()
# Out:
# 0

# %%
df["Max_Power"].value_counts()
# Out:
# 150 Watts    241
# 75 Watts     158
# 120 Watts    151
# 250 Watts    135
# 65 Watts      92
#             ...
# 540 Watts      1
# 109 Watts      1
# 410 Watts      1
# 113 Watts      1
# 236 Watts      1
# Name: Max_Power, Length: 192, dtype: int64

# %%
max_Max_Power = df["Max_Power"].value_counts().idxmax()
print(max_Max_Power)
# Out:
# 150 Watts

# %%
df["Max_Power"].replace(np.nan, max_Max_Power, inplace=True)

# %%
df.head(20)
# Out:
#                   Architecture Best_Resolution Boost_Clock Core_Speed  \
# 0                  Tesla G92b      1920 x 1080   1050 MHz     738 MHz
# 1                     R600 XT       1366 x 768   1050 MHz    1000 MHz
# 2                    R600 PRO       1366 x 768   1050 MHz    1000 MHz
# 3                       RV630       1024 x 768   1050 MHz    1000 MHz
# 4                       RV630       1024 x 768   1050 MHz    1000 MHz
# 5                       RV630       1024 x 768   1050 MHz    1000 MHz
# 6               R700 RV790 XT      1920 x 1080   1050 MHz     870 MHz
# 7                     R600 GT       1024 x 768   1050 MHz    1000 MHz
# 8              Pitcairn XT GL      1920 x 1080   1050 MHz    1000 MHz
# 9                       RV100      1920 x 1080   1050 MHz    1000 MHz
# 10                  NV28GL A2      1920 x 1080   1050 MHz    1000 MHz
# 11                Fermi GF110      1920 x 1080   1050 MHz     650 MHz
# ...

# %%
df["Max_Power"].isnull().sum()
# Out:
# 0

# %%
df["Memory"].value_counts()
# Out:
# 2048 MB      799
# 1024 MB      624
# 4096 MB      459
# 8192 MB      216
# 3072 MB      176
# 512 MB       158
# 256 MB       136
# 6144 MB      117
# 128 MB        61
# 11264 MB      47
# 1536 MB       31
# 64 MB         26
# 12288 MB      25
# 1280 MB       18
# 16384 MB      12
# 32 MB         11
# 768 MB         8
# 896 MB         8
# 1792 MB        6
# 2560 MB        4
# 384 MB         2
# 640 MB         2
# 16 MB          2
# 24576 MB       2
# 1720 MB        1
# 5120 MB        1
# 32000 MB       1
# 9216 MB        1
# 320 MB         1
# Name: Memory, dtype: int64

# %%
max_Memory = df["Memory"].value_counts().idxmax()
print(max_Memory)
# Out:
# 2048 MB

# %%
df["Memory"].replace(np.nan, max_Memory, inplace=True)

# %%
df.head(20)
# Out:
#                   Architecture Best_Resolution Boost_Clock Core_Speed  \
# 0                  Tesla G92b      1920 x 1080   1050 MHz     738 MHz
# 1                     R600 XT       1366 x 768   1050 MHz    1000 MHz
# 2                    R600 PRO       1366 x 768   1050 MHz    1000 MHz
# 3                       RV630       1024 x 768   1050 MHz    1000 MHz
# 4                       RV630       1024 x 768   1050 MHz    1000 MHz
# 5                       RV630       1024 x 768   1050 MHz    1000 MHz
# 6               R700 RV790 XT      1920 x 1080   1050 MHz     870 MHz
# 7                     R600 GT       1024 x 768   1050 MHz    1000 MHz
# 8              Pitcairn XT GL      1920 x 1080   1050 MHz    1000 MHz
# 9                       RV100      1920 x 1080   1050 MHz    1000 MHz
# 10                  NV28GL A2      1920 x 1080   1050 MHz    1000 MHz
# 11                Fermi GF110      1920 x 1080   1050 MHz     650 MHz
# ...

# %%
df["Memory"].isnull().sum()
# Out:
# 0

# %%
df["Memory_Bandwidth"].value_counts()
# Out:
# 25.6GB/sec     162
# 28.8GB/sec     102
# 224.4GB/sec     94
# 12.8GB/sec      85
# 192.3GB/sec     81
#               ...
# 10.4GB/sec       1
# 397.3GB/sec      1
# 12.2GB/sec       1
# 108.3GB/sec      1
# 136GB/sec        1
# Name: Memory_Bandwidth, Length: 336, dtype: int64

# %%
max_Memory_Bandwidth = df["Memory_Bandwidth"].value_counts().idxmax()
print(max_Memory_Bandwidth)
# Out:
# 25.6GB/sec

# %%
df["Memory_Bandwidth"].replace(np.nan, max_Memory_Bandwidth, inplace=True)

# %%
df.head(20)
# Out:
#                   Architecture Best_Resolution Boost_Clock Core_Speed  \
# 0                  Tesla G92b      1920 x 1080   1050 MHz     738 MHz
# 1                     R600 XT       1366 x 768   1050 MHz    1000 MHz
# 2                    R600 PRO       1366 x 768   1050 MHz    1000 MHz
# 3                       RV630       1024 x 768   1050 MHz    1000 MHz
# 4                       RV630       1024 x 768   1050 MHz    1000 MHz
# 5                       RV630       1024 x 768   1050 MHz    1000 MHz
# 6               R700 RV790 XT      1920 x 1080   1050 MHz     870 MHz
# 7                     R600 GT       1024 x 768   1050 MHz    1000 MHz
# 8              Pitcairn XT GL      1920 x 1080   1050 MHz    1000 MHz
# 9                       RV100      1920 x 1080   1050 MHz    1000 MHz
# 10                  NV28GL A2      1920 x 1080   1050 MHz    1000 MHz
# 11                Fermi GF110      1920 x 1080   1050 MHz     650 MHz
# ...

# %%
df["Memory_Bandwidth"].isnull().sum()
# Out:
# 0

# %%
df["Memory_Bus"].value_counts()
# Out:
# 128 Bit      1363
# 256 Bit       909
# 64 Bit        380
# 384 Bit       255
# 192 Bit       193
# 512 Bit        97
# 88 Bit         29
# 320 Bit        24
# 448 Bit        14
# 352 Bit        14
# 32 Bit         13
# 4096 Bit        7
# 176 Bit         4
# 768 Bit         2
# 8192 Bit        1
# 96 Bit          1
# 3072 Bit        1
# Name: Memory_Bus, dtype: int64

# %%
max_Memory_Bus = df["Memory_Bus"].value_counts().idxmax()
print(max_Max_Power)
# Out:
# 150 Watts

# %%
df["Memory_Bus"].replace(np.nan, max_Memory_Bus, inplace=True)

# %%
df.head(20)
# Out:
#                   Architecture Best_Resolution Boost_Clock Core_Speed  \
# 0                  Tesla G92b      1920 x 1080   1050 MHz     738 MHz
# 1                     R600 XT       1366 x 768   1050 MHz    1000 MHz
# 2                    R600 PRO       1366 x 768   1050 MHz    1000 MHz
# 3                       RV630       1024 x 768   1050 MHz    1000 MHz
# 4                       RV630       1024 x 768   1050 MHz    1000 MHz
# 5                       RV630       1024 x 768   1050 MHz    1000 MHz
# 6               R700 RV790 XT      1920 x 1080   1050 MHz     870 MHz
# 7                     R600 GT       1024 x 768   1050 MHz    1000 MHz
# 8              Pitcairn XT GL      1920 x 1080   1050 MHz    1000 MHz
# 9                       RV100      1920 x 1080   1050 MHz    1000 MHz
# 10                  NV28GL A2      1920 x 1080   1050 MHz    1000 MHz
# 11                Fermi GF110      1920 x 1080   1050 MHz     650 MHz
# ...

# %%
df["Memory_Bus"].isnull().sum()
# Out:
# 0

# %%
df["Memory_Speed"].value_counts()
# Out:
# 800 MHz     280
# 900 MHz     206
# 1753 MHz    201
# 1502 MHz    196
# 1250 MHz    193
#            ...
# 1280 MHz      1
# 1120 MHz      1
# 747 MHz       1
# 1683 MHz      1
# 1180 MHz      1
# Name: Memory_Speed, Length: 186, dtype: int64

# %%
max_Memory_Speed = df["Memory_Speed"].value_counts().idxmax()
print(max_Max_Power)
# Out:
# 150 Watts

# %%
df["Memory_Speed"].replace(np.nan, max_Memory_Speed, inplace=True)

# %%
df.head(20)
# Out:
#                   Architecture Best_Resolution Boost_Clock Core_Speed  \
# 0                  Tesla G92b      1920 x 1080   1050 MHz     738 MHz
# 1                     R600 XT       1366 x 768   1050 MHz    1000 MHz
# 2                    R600 PRO       1366 x 768   1050 MHz    1000 MHz
# 3                       RV630       1024 x 768   1050 MHz    1000 MHz
# 4                       RV630       1024 x 768   1050 MHz    1000 MHz
# 5                       RV630       1024 x 768   1050 MHz    1000 MHz
# 6               R700 RV790 XT      1920 x 1080   1050 MHz     870 MHz
# 7                     R600 GT       1024 x 768   1050 MHz    1000 MHz
# 8              Pitcairn XT GL      1920 x 1080   1050 MHz    1000 MHz
# 9                       RV100      1920 x 1080   1050 MHz    1000 MHz
# 10                  NV28GL A2      1920 x 1080   1050 MHz    1000 MHz
# 11                Fermi GF110      1920 x 1080   1050 MHz     650 MHz
# ...

# %%
df["Memory_Speed"].isnull().sum()
# Out:
# 0

# %%
df.to_csv('Data_wrangling_PART_1.csv')
